# %%
# %reload_ext autoreload
% autoreload 2

from SPN2 import SPN
import tensorflow as tf
import numpy as np

# %%
spn = SPN()
#spn.make_random_model(((2, 8), (8, 12)), 16, 1, cont=False, classify=False)
spn.make_fast_model_from_file("../Modelz/nltcs.spn.txt", False, cont=False, classify=False)
spn.start_session()
# Out:
# print ur mom
# 2
# 787
# /Users/PhyrexianDragon/anaconda/lib/python2.7/site-packages/tensorflow/python/ops/gradients.py:90: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
w1 = spn.model.session.run(spn.model.weights)

# %%
w1[0].shape
# Out:
# (1574,)

# %%
spn.add_data('../Dataz/' + 'nltcs' + '.ts.data', 'train', True)
spn.add_data('../Dataz/' + 'nltcs' + '.test.data', 'test')
# Out:
# zebra
# ../Dataz/nltcs.ts.data
# ../Dataz/nltcs.test.data

# %%
spn.train(1, spn.data.train, minibatch_size=1000, count=True, gd=True)
# Out:
# Epoch 0
# 1 / 17
# 2 / 17
# 3 / 17
# 4 / 17
# 5 / 17
# 6 / 17
# 7 / 17
# 8 / 17
# 9 / 17
# 10 / 17
# 11 / 17
# 12 / 17
# 13 / 17
# 14 / 17
# 15 / 17
# 16 / 17
# 17 / 17
# 6.05033522438

# %%
spn.model.unbuild_fast_variables()
spn.model.clean_nodes(0.01)
spn.model.save("../Modelz/nltcs.tespn.txt")

# %%
spn2 = SPN()
#spn.make_random_model(((2, 5), (2, 5)), 16, 1, cont=False, classify=False)
spn2.make_fast_model_from_file("../Modelz/nltcs.tespn.txt", False, cont=False, classify=False)
spn2.start_session()
# Out:
# print ur mom
# 2
# 750

# %%
print spn2.model.session.run(spn2.model.loss, {spn2.model.input: spn.data.test})
print spn2.model.session.run(spn2.model.loss, {spn2.model.input: spn.data.train})
print spn.model.session.run(spn.model.loss, {spn.model.input: spn.data.test})
print spn.model.session.run(spn.model.loss, {spn.model.input: spn.data.train})
print spn2.evaluate(spn.data.test)
# Out:
# 6.14893500426
# 6.06890038108
# 6.14623429069
# 6.06698192338
# 1 / 4
# 2 / 4
# 3 / 4
# 4 / 4
# 6.14893500426

# %%
spn2.model.normalize_weights()

# %%
spn2.train(15, spn.data.train)
# Out:
# Epoch 0
# 1 / 32
# 2 / 32
# 3 / 32
# 4 / 32
# 5 / 32
# 6 / 32
# 7 / 32
# 8 / 32
# 9 / 32
# 10 / 32
# 11 / 32
# 12 / 32
# 13 / 32
# 14 / 32
# 15 / 32
# 16 / 32
# 17 / 32
# 18 / 32
# 19 / 32
# 20 / 32
# 21 / 32
# 22 / 32
# 23 / 32
# 24 / 32
# 25 / 32
# 26 / 32
# 27 / 32
# 28 / 32
# 29 / 32
# 30 / 32
# 31 / 32
# 32 / 32
# 6.0608120805
# Epoch 1
# 1 / 32
# 2 / 32
# 3 / 32
# 4 / 32
# 5 / 32
# 6 / 32
# 7 / 32
# 8 / 32
# 9 / 32
# 10 / 32
# 11 / 32
# 12 / 32
# 13 / 32
# 14 / 32
# 15 / 32
# 16 / 32
# 17 / 32
# 18 / 32
# 19 / 32
# 20 / 32
# 21 / 32
# 22 / 32
# 23 / 32
# 24 / 32
# 25 / 32
# 26 / 32
# 27 / 32
# 28 / 32
# 29 / 32
# 30 / 32
# 31 / 32
# 32 / 32
# 6.03510144228
# Epoch 2
# 1 / 32
# 2 / 32
# 3 / 32
# 4 / 32
# 5 / 32
# 6 / 32
# 7 / 32
# 8 / 32
# 9 / 32
# 10 / 32
# 11 / 32
# 12 / 32
# 13 / 32
# 14 / 32
# 15 / 32
# 16 / 32
# 17 / 32
# 18 / 32
# 19 / 32
# 20 / 32
# 21 / 32
# 22 / 32
# 23 / 32
# 24 / 32
# 25 / 32
# 26 / 32
# 27 / 32
# 28 / 32
# 29 / 32
# 30 / 32
# 31 / 32
# 32 / 32
# 6.02659346796
# Epoch 3
# 1 / 32
# 2 / 32
# 3 / 32
# 4 / 32
# 5 / 32
# 6 / 32
# 7 / 32
# 8 / 32
# 9 / 32
# 10 / 32
# 11 / 32
# 12 / 32
# 13 / 32
# 14 / 32
# 15 / 32
# 16 / 32
# 17 / 32
# 18 / 32
# 19 / 32
# 20 / 32
# 21 / 32
# 22 / 32
# 23 / 32
# 24 / 32
# 25 / 32
# 26 / 32
# 27 / 32
# 28 / 32
# 29 / 32
# 30 / 32
# 31 / 32
# 32 / 32
# 6.0209461388
# Epoch 4
# 1 / 32
# 2 / 32
# 3 / 32
# 4 / 32
# 5 / 32
# 6 / 32
# 7 / 32
# 8 / 32
# 9 / 32
# 10 / 32
# 11 / 32
# 12 / 32
# 13 / 32
# 14 / 32
# 15 / 32
# 16 / 32
# 17 / 32
# 18 / 32
# 19 / 32
# 20 / 32
# 21 / 32
# 22 / 32
# 23 / 32
# 24 / 32
# 25 / 32
# 26 / 32
# 27 / 32
# 28 / 32
# 29 / 32
# 30 / 32
# 31 / 32
# 32 / 32
# 6.0167788491
# Epoch 5
# 1 / 32
# 2 / 32
# 3 / 32
# 4 / 32
# 5 / 32
# 6 / 32
# 7 / 32
# 8 / 32
# 9 / 32
# 10 / 32
# 11 / 32
# 12 / 32
# 13 / 32
# 14 / 32
# 15 / 32
# 16 / 32
# 17 / 32
# 18 / 32
# 19 / 32
# 20 / 32
# 21 / 32
# 22 / 32
# 23 / 32
# 24 / 32
# 25 / 32
# 26 / 32
# 27 / 32
# 28 / 32
# 29 / 32
# 30 / 32
# 31 / 32
# 32 / 32
# 6.01367146159
# Epoch 6
# 1 / 32
# 2 / 32
# 3 / 32
# 4 / 32
# 5 / 32
# 6 / 32
# 7 / 32
# 8 / 32
# 9 / 32
# 10 / 32
# 11 / 32
# 12 / 32
# 13 / 32
# 14 / 32
# 15 / 32
# 16 / 32
# 17 / 32
# 18 / 32
# 19 / 32
# 20 / 32
# 21 / 32
# 22 / 32
# 23 / 32
# 24 / 32
# 25 / 32
# 26 / 32
# 27 / 32
# 28 / 32
# 29 / 32
# 30 / 32
# 31 / 32
# 32 / 32
# 6.01107670918
# Epoch 7
# 1 / 32
# 2 / 32
# 3 / 32
# 4 / 32
# 5 / 32
# 6 / 32
# 7 / 32
# 8 / 32
# 9 / 32
# 10 / 32
# 11 / 32
# 12 / 32
# 13 / 32
# 14 / 32
# 15 / 32
# 16 / 32
# 17 / 32
# 18 / 32
# 19 / 32
# 20 / 32
# 21 / 32
# 22 / 32
# 23 / 32
# 24 / 32
# 25 / 32
# 26 / 32
# 27 / 32
# 28 / 32
# 29 / 32
# 30 / 32
# 31 / 32
# 32 / 32
# 6.008989145
# Epoch 8
# 1 / 32
# 2 / 32
# 3 / 32
# 4 / 32
# 5 / 32
# 6 / 32
# 7 / 32
# 8 / 32
# 9 / 32
# 10 / 32
# 11 / 32
# 12 / 32
# 13 / 32
# 14 / 32
# 15 / 32
# 16 / 32
# 17 / 32
# 18 / 32
# 19 / 32
# 20 / 32
# 21 / 32
# 22 / 32
# 23 / 32
# 24 / 32
# 25 / 32
# 26 / 32
# 27 / 32
# 28 / 32
# 29 / 32
# 30 / 32
# 31 / 32
# 32 / 32
# 6.00723108457
# Epoch 9
# 1 / 32
# 2 / 32
# 3 / 32
# 4 / 32
# 5 / 32
# 6 / 32
# 7 / 32
# 8 / 32
# 9 / 32
# 10 / 32
# 11 / 32
# 12 / 32
# 13 / 32
# 14 / 32
# 15 / 32
# 16 / 32
# 17 / 32
# 18 / 32
# 19 / 32
# 20 / 32
# 21 / 32
# 22 / 32
# 23 / 32
# 24 / 32
# 25 / 32
# 26 / 32
# 27 / 32
# 28 / 32
# 29 / 32
# 30 / 32
# 31 / 32
# 32 / 32
# 6.0058321527
# Epoch 10
# 1 / 32
# 2 / 32
# 3 / 32
# 4 / 32
# 5 / 32
# 6 / 32
# 7 / 32
# 8 / 32
# 9 / 32
# 10 / 32
# 11 / 32
# 12 / 32
# 13 / 32
# 14 / 32
# 15 / 32
# 16 / 32
# 17 / 32
# 18 / 32
# 19 / 32
# 20 / 32
# 21 / 32
# 22 / 32
# 23 / 32
# 24 / 32
# 25 / 32
# 26 / 32
# 27 / 32
# 28 / 32
# 29 / 32
# 30 / 32
# 31 / 32
# 32 / 32
# 6.0046535175
# Epoch 11
# 1 / 32
# 2 / 32
# 3 / 32
# 4 / 32
# 5 / 32
# 6 / 32
# 7 / 32
# 8 / 32
# 9 / 32
# 10 / 32
# 11 / 32
# 12 / 32
# 13 / 32
# 14 / 32
# 15 / 32
# 16 / 32
# 17 / 32
# 18 / 32
# 19 / 32
# 20 / 32
# 21 / 32
# 22 / 32
# 23 / 32
# 24 / 32
# 25 / 32
# 26 / 32
# 27 / 32
# 28 / 32
# 29 / 32
# 30 / 32
# 31 / 32
# 32 / 32
# 6.00368535293
# Epoch 12
# 1 / 32
# 2 / 32
# 3 / 32
# 4 / 32
# 5 / 32
# 6 / 32
# 7 / 32
# 8 / 32
# 9 / 32
# 10 / 32
# 11 / 32
# 12 / 32
# 13 / 32
# 14 / 32
# 15 / 32
# 16 / 32
# 17 / 32
# 18 / 32
# 19 / 32
# 20 / 32
# 21 / 32
# 22 / 32
# 23 / 32
# 24 / 32
# 25 / 32
# 26 / 32
# 27 / 32
# 28 / 32
# 29 / 32
# 30 / 32
# 31 / 32
# 32 / 32
# 6.00278375576
# Epoch 13
# 1 / 32
# 2 / 32
# 3 / 32
# 4 / 32
# 5 / 32
# 6 / 32
# 7 / 32
# 8 / 32
# 9 / 32
# 10 / 32
# 11 / 32
# 12 / 32
# 13 / 32
# 14 / 32
# 15 / 32
# 16 / 32
# 17 / 32
# 18 / 32
# 19 / 32
# 20 / 32
# 21 / 32
# 22 / 32
# 23 / 32
# 24 / 32
# 25 / 32
# 26 / 32
# 27 / 32
# 28 / 32
# 29 / 32
# 30 / 32
# 31 / 32
# 32 / 32
# 6.00204879865
# Epoch 14
# 1 / 32
# 2 / 32
# 3 / 32
# 4 / 32
# 5 / 32
# 6 / 32
# 7 / 32
# 8 / 32
# 9 / 32
# 10 / 32
# 11 / 32
# 12 / 32
# 13 / 32
# 14 / 32
# 15 / 32
# 16 / 32
# 17 / 32
# 18 / 32
# 19 / 32
# 20 / 32
# 21 / 32
# 22 / 32
# 23 / 32
# 24 / 32
# 25 / 32
# 26 / 32
# 27 / 32
# 28 / 32
# 29 / 32
# 30 / 32
# 31 / 32
# 32 / 32
# 6.0013996095

# %%
print w1[4]
# Out:
# [ 0.23721503  0.28897104  0.10782502  0.15157116  0.06962415  0.06900801
#   0.01971657  0.02649415  0.02957486  0.19883608  0.75363725  0.03516004
#   0.01236663  0.65907522  0.24223602  0.0510697   0.02070393  0.01242236
#   0.01449275  0.10363924  0.57120253  0.18037975  0.07120253  0.03718354
#   0.03639241  0.55617089  0.3085443   0.05775316  0.07753165  0.36991643
#   0.33871866  0.15933148  0.04623955  0.0551532   0.03064067  0.55915493
#   0.21549296  0.08028169  0.06478873  0.03802817  0.0056338   0.03661972
#   0.70081061  0.27560796  0.02358143  0.80766396  0.11864407  0.04568902
#   0.02063375  0.00294768  0.00294768  0.00147384  0.37094017  0.21196581
#   0.36239316  0.00854701  0.02905983  0.01709402  0.4381068   0.19660194
#   0.02063107  0.12135922  0.04004854  0.06917476  0.01699029  0.09708738
#   0.28858218  0.62735257  0.05144291  0.03262233  0.30112923  0.24843162
#   0.29611041  0.05771644  0.01505646  0.02634881  0.01003764  0.02258469
#   0.02258469  0.15558344  0.50439147  0.32245922  0.01756587  0.24335106
#   0.53590426  0.06914894  0.03324468  0.07978723  0.02925532  0.00930851
#   0.86303191  0.05718085  0.0518617   0.02792553  0.53432836  0.19701493
#   0.16119403  0.10746269]

# %%
print w1[2]
# Out:
# [ 0.09714286  0.50857143  0.19428571  0.2         0.20731707  0.42276423
#   0.3699187   0.2920354   0.61061947  0.07964602  0.01769912  0.16439791
#   0.68062827  0.15497382  0.54700855  0.15669516  0.19088319  0.10541311
#   0.25069252  0.69252078  0.0567867   0.35542169  0.42168675  0.15662651
#   0.06626506  0.42105263  0.5401662   0.03878116]

# %%
print w2[0] - w1[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-1dc5a0c3cbe0> in <module>()
# ----> 1 print w2[0] - w1[0]
#
# NameError: name 'w2' is not defined
